# %% [markdown]
# ## mcmc plots

# %%
# %matplotlib inline
from anesthetic import MCMCSamples
mcmc_root = 'outputs/test_posteriors'
mcmc = MCMCSamples(root=mcmc_root)

# %%
fig, axes = mcmc.plot_1d('m')

# %%
fig, axes = mcmc.plot_1d(['m', 'c']);
fig.tight_layout()

# %%
mcmc.plot_2d(['m', 'c'], types={'lower':'kde','diagonal':'kde'});

# %% [markdown]
# ## Nested sampling plotting

# %%
from anesthetic import NestedSamples
nested_root = 'outputs/test'
nested = NestedSamples(root=nested_root)

# %% [markdown]
# We can infer the evidence, KL divergence and Bayesian model dimensionality:

# %%
ns_output = nested.ns_output()

# %% [markdown]
# Bayesian evidence, KL divergence (D) and Bayesian model dimensionality (d)

# %%
ns_output[:6]
# Out:
#          logZ          D         d
# 0 -513.585340  17.895130  4.962716
# 1 -509.374530  13.422863  6.136573
# 2 -510.433497  14.571813  6.066217
# 3 -512.019258  16.275849  6.178290
# 4 -509.524964  13.682554  5.668257
# 5 -509.516660  13.775493  5.732283

# %%
for x in ns_output:
    print('%10s = %9.2f +/- %4.2f' % (x, ns_output[x].mean(), ns_output[x].std()))
# Out:
#       logZ =   -509.93 +/- 1.29
#          D =     14.10 +/- 1.27
#          d =      5.68 +/- 0.37

# %%
from anesthetic import make_1d_axes
fig, axes = make_1d_axes(['logZ', 'D', 'd'], ncols=3, tex=ns_output.tex)
ns_output.plot_1d(axes);

# %%
fig, axes = mcmc.plot_2d(['m','c'])
nested.plot_2d(axes=axes);

# %%
# %matplotlib
# Out:
# Using matplotlib backend: nbAgg

# %%
nested.gui()
# Out:
# <img src="data:image/png;base64,..." width="431.93333333333334">

# %%
# %matplotlib notebook

# %%
nested.gui()
# Out:
# <img src="data:image/png;base64,..." width="627.6333333333333">
